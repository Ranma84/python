# %% [markdown]
# # Una variable es un espacio para almacenar datos modificables, en la memoria de un ordenador

# %% [markdown]
# |  Tipo de Variable  | Tipo de Variable (inglés) | type() |
# |:------------------:|:-------------------------:|:------:|
# |       Entero       |          Integer          |   int  |
# |   Punto flotante   |      Floating points      |  float |
# | Cadena de Caracter |           String          |   str  |
# |       Listas       |           Lists           |  list  |
# |    Diccionarios    |        Dictionaries       |  dict  |
# |       Tuplas       |           Tuples          |   tuple|
# |        Sets        |            Sets           |   set  |
# |     Dato lógico    |          Booleans         |  bool  |

# %% [markdown]
# - Los tipos están asociados con los valores, no con la variable en sí.
#
# - Una misma variable puede almacenar múltiples tipos de datos.
#
# - NO es necesario especificar el tipo de variable.

# %% [markdown]
# *   No se pueden usar nombres restringidos por Python.
# *   No se puede comenzar con un número o un símbolo.

# %% [markdown]
# - Se recomienda usar el snakeCase para nombrar variables.
# - Las constantes se escriben complemente en mayúsculas y separados por guiones bajos.

# %%
numeroDecimal = 3.0  # Camel Case
numero_decimal = 3.0  # Snake Case

# %%
numero = 1234
type(numero)
# Out:
# int

# %%
# 1numero = 123
# $numero = 123

# %%
PI = 3.1415
ACELERACION_GRAVEDAD = 9.8

# %%
nombre = 'Dayron'
type(nombre)
# Out:
# str

# %%
lista = [1, 2, 3, 4, 'rumbaut']
type(lista)
# Out:
# list

# %%
diccionario = {'numero': 123, 'nombre': 'selene', 'estado': True}
type(diccionario)
# Out:
# dict

# %%
tupla = (1, 2, 3, 4, 'hola', 1.34)
type(tupla)
# Out:
# tuple

# %%
booleana = True
type(booleana)
# Out:
# bool
